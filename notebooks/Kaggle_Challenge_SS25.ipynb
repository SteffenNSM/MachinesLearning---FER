# %% [markdown]
# <a href="https://colab.research.google.com/github/SteffenNSM/MachinesLearning---FER/blob/main/notebooks/Kaggle_Challenge_SS25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Baseline Notebook – Kaggle Challenge SS 2025

# %% [markdown]
# ## Setup & Kaggle API

# %%
# Setup & Configuration
from google.colab import files
files.upload()
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-d17c0195-f00a-4ece-8ead-b6c8195f206e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d17c0195-f00a-4ece-8ead-b6c8195f206e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Download data
# !kaggle competitions download -c aiim-technical-challenge-2025
# Out:
# aiim-technical-challenge-2025.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# Unzip files
# !unzip aiim-technical-challenge-2025.zip
# !tar -xvzf train_images.tar.gz
# !tar -xvzf test_images.tar.gz
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#   inflating: aiim-emotion-classification/train/happy/Kaggle19201.jpg
#   inflating: aiim-emotion-classification/train/happy/Kaggle19261.jpg
#   inflating: aiim-emotion-classification/train/happy/Kaggle19302.jpg
#   inflating: aiim-emotion-classification/train/happy/Kaggle19349.jpg
#   inflating: aiim-emotion-classification/train/happy/Kaggle19354.jpg
#   inflating: aiim-emotion-classification/train/happy/Kaggle1937.jpg
#   inflating: aiim-emotion-classification/train/happy/Kaggle19378.jpg
#   inflating: aiim-emotion-classification/train/happy/Kaggle19410.jpg
#   inflating: aiim-emotion-classification/train/happy/Kaggle19424.jpg
#   inflating: aiim-emotion-classification/train/happy/Kaggle19427.jpg
#   inflating: aiim-emotion-classification/train/happy/Kaggle19440.jpg
#   inflating: aiim-emotion-classification/train/happy/Kaggle19448.jpg
#   inflating: aiim-emotion-classification/train/happy/Kaggle19485.jpg
# ...

# %% [markdown]
# ## Test

# %%
import os

for root, dirs, files in os.walk(".", topdown=True):
    print(root)
    dirs[:] = dirs[:2]  # nur die obersten zwei Ebenen anzeigen
# Out:
# .
# ./.config
# ./.config/configurations
# ./.config/logs
# ./.config/logs/2025.05.13
# ./aiim-emotion-classification
# ./aiim-emotion-classification/train
# ./aiim-emotion-classification/train/surprise
# ./aiim-emotion-classification/train/happy
# ./aiim-emotion-classification/test

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

def show_example_images(label, num=5):
    """
    Zeigt Beispielbilder aus einer bestimmten Emotionsklasse.

    Parameter:
    label (str): Name des Emotion-Ordners, z. B. 'happy', 'sad', 'angry'
    num (int): Anzahl der Bilder, die angezeigt werden sollen
    """
    path = f'aiim-emotion-classification/train/{label}'

    if not os.path.exists(path):
        print(f"Pfad nicht gefunden: {path}")
        return

    files = os.listdir(path)[:num]
    if not files:
        print(f"Keine Dateien im Ordner {path} gefunden.")
        return

    plt.figure(figsize=(num * 2, 3))
    for i, file in enumerate(files):
        img = mpimg.imread(os.path.join(path, file))
        plt.subplot(1, num, i + 1)
        plt.imshow(img)
        plt.axis('off')
        plt.title(label)
    plt.show()

# %%
show_example_images("happy", 5)
show_example_images("surprise", 5)
